# %%
x = [1, 2, 3, 1, 1, 1, 1, 1]

# %%
y = {1, 1, 1, 1, 1, 2}
y
# Out:
# {1, 2}

# %%
dic = {
    'A' : 7,
    'B' : 10
}

# %%
x[:]
# Out:
# [1, 2, 3, 1, 1, 1, 1, 1]

# %%
y[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s = set([1,1,1,1,1,1,1,1,3,4,5,2,3,3,3,3,3])
s
# Out:
# {1, 2, 3, 4, 5}

# %%
list = [1,2,3]
list.append(4)
list
# Out:
# [1, 2, 3, 4]

# %%
s.add(7)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
set('ali hejazi')
# Out:
# {' ', 'a', 'e', 'h', 'i', 'j', 'l', 'z'}

# %%
s = {'ali',1, (1,2,3), int}

# %%
len(s)
# Out:
# 4

# %%
2 in s
# Out:
# False

# %%
1 in s
# Out:
# True

# %%
'ali' not in s
# Out:
# False

# %%
fs = frozenset([1,2,3])

# %%
fs
# Out:
# frozenset({1, 2, 3})

# %%
x = [1,2,3]

# %%
x = (1,2,3)

# %%
x = {'a':1}

# %%
x={1,2,3}
