# %%
x = [1,2,3]
len(x)
# Out:
# 3

# %%
def add(a, b):
    pass # offside rule

# %%
add(2, 3)

# %%
def empty():
    print('its empty dude, what else do you expect ?')

# %%
empty()
# Out:
# its empty dude, what else do you expect ?

# %%
def f(qty, item, price = 10): # formal & defualt parameters
    print(f'{qty} {item}s costs {price}$ ')

# %%
f(2, 'Banana', 5) # actual parameters
# Out:
# 2 Bananas costs 5$

# %%
f(item='banana', qty=2,price=5)
# Out:
# 2 bananas costs 5$

# %%
def f(l):
    l.append('#')
    return l

# %%
x = f([1,3,5,7])
print(x)
# Out:
# [1, 3, 5, 7, '#']
