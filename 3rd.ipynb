# %%
2 + 3
# Out:
# 5

# %%
a = 3
b = 4

# %%
-a
# Out:
# -3

# %%
-(a+b)
# Out:
# -7

# %%
+(-a)
# Out:
# -3

# %%
a / b
# Out:
# 0.75

# %%
a % b
# Out:
# 3

# %%
a // b
# Out:
# 0

# %%
a = 12
b = 5

# %%
a // b
# Out:
# 2

# %%
25 ** 2
# Out:
# 625

# %%
3 < 4
# Out:
# True

# %%
3 == 4
# Out:
# False

# %%
3 > 4
# Out:
# False

# %%
3 <= 3
# Out:
# True

# %%
tolerance = 0.000001
y = 3.3
b = 1.1 + 2.2 
y - b < tolerance
# Out:
# True

# %%
not (10 < 9)
# Out:
# True

# %%
bool(0+0)
# Out:
# False

# %%
name = ''

# %%
if not name:
    print('Name is required')
# Out:
# Name is required

# %%
bool(None)
import numpy as np

# %%
x = np.array([1, 2, 3])

# %%
x
# Out:
# array([1, 2, 3])

# %%
~x
# Out:
# array([-2, -3, -4])

# %%
x = x + 10
x += 10
