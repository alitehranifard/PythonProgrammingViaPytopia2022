# %%
n=6
for i in range(1, 11):
    print(f'{n} x {i} = {i * n}')
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
num_str = '123.2'
numbers = set('.123456789')
for char in num_str :
    if char not in numbers:
        print('The char is not a number!')
        break
    else:
        print(num_str,'is a number')
# Out:
# 123.2 is a number
# 123.2 is a number
# 123.2 is a number
# 123.2 is a number
# 123.2 is a number

# %%
msg = int(input('Please enter your number'))

# %%
msg
# Out:
# 26

# %%
type(msg)
# Out:
# int

# %%
print(f'your number is {msg}')
# Out:
# your number is 26

# %%
print('hello','world','ali', sep='...')
# Out:
# hello...world...ali

# %%
for i in range(10):
    print(i**2,end='**')
# Out:
# 0**1**4**9**16**25**36**49**64**81**

# %%
quantity = 6
fruit = 'banana'
price = 3
'6 bananas cost 20$'
'{} is stupid'.format('Ali')
# Out:
# 'Ali is stupid'

# %%
'{} {}s cost {}$'.format(quantity,fruit,price)
# Out:
# '6 bananas cost 3$'

# %%
'{0} {n} {1}'.format(2, 'Reza', n='Niloufar')
# Out:
# '2 Niloufar Reza'

# %%
z = 2 + 3j

# %%
'{0.imag}'.format(z)
# Out:
# '3.0'

# %%
str(2)
# Out:
# '2'

# %%
ascii(2)
# Out:
# '2'

# %%
repr(2)
# Out:
# '2'

# %%
'name: {:e}'.format(444)
# Out:
# 'name: 4.440000e+02'

# %%
x = 2

# %%
y = 3

# %%
f'{x} is not {y}'
# Out:
# '2 is not 3'
