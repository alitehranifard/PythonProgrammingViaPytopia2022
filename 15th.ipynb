# %%
mixed_tuple = ('Orange', [10, 20, 30], (5, 15, 25))
value_20 = mixed_tuple[1][1]
value_20
# Out:
# 20

# %%
char_g = mixed_tuple[0][4]
char_g
# Out:
# 'g'

# %%
num_tup = (10, 20, 30, 40, 50)
reversed_num_tup = num_tup[::-1]
reversed_num_tup
# Out:
# (50, 40, 30, 20, 10)

# %%
shahnameh_tuple = ('Sohrab', 'Faramarz', 'Jahangir', 'Siyavash', 'Dariush')
s, f, j, si, d = shahnameh_tuple
s
# Out:
# 'Sohrab'

# %%
_ = 3
_
# Out:
# 3

# %%
s, *_, si = shahnameh_tuple

# %%
_
# Out:
# ['Faramarz', 'Jahangir', 'Siyavash']

# %%
tuple1 = (11, 22, 33, 44, 55, 66)
tuple2 = tuple1[3:5]
tuple2
# Out:
# (44, 55)

# %%
persian_poets = 'saadi', 'frough', 'hafez', 'parvin', 'saeb'
persian_poets_wo_hafez = persian_poets[:2] + persian_poets[3:]
persian_poets_wo_hafez
# Out:
# ('saadi', 'frough', 'parvin', 'saeb')
