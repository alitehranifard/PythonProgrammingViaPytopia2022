# %%
import numpy as np
x = np.array([1,2,3])
# imperative
def double(mylist):
    return x * 2

# %%
double(x)
# Out:
# array([2, 4, 6])

# %%
## declerative
double_list = list(map(lambda num: num*2, x))
print(double_list)
# Out:
# [2, 4, 6]
