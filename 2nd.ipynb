# %%
x = 2

# %%
print(x)
# Out:
# 2

# %%
x = 'ali'

# %%
print(x)
# Out:
# ali

# %%
a = b = c = 4

# %%
x = 2

# %%
type(x)
# Out:
# int

# %%
m = x

# %%
 m = 400

# %%
n = 'foo'

# %%
id(m)
# Out:
# 2743101846256

# %%
id(n)
# Out:
# 2743047247680

# %%
m is n
# Out:
# False

# %%
n is n
# Out:
# True

# %%
n is x
# Out:
# False

# %%
x is x
# Out:
# True

# %%
n = 2

# %%
y = 2

# %%
id(m)
# Out:
# 2743101846256

# %%
id(y)
# Out:
# 140713251240408

# %%
y = n = 2

# %%
y is n
# Out:
# True

# %%
id(y)
# Out:
# 140713251240408

# %%
id(n)
# Out:
# 140713251240408

# %%
y == n
# Out:
# True

# %%
first_name = 'ali'

# %%
last_name = 'jeldian'

# %%
age='22'

# %%
2_name = 'ali'
# Out:
#   Cell In[32], line 1
#     2_name = 'ali'
#      ^
# SyntaxError: invalid decimal literal

# %%
x.y = 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x.y = 2
#
# AttributeError: 'int' object has no attribute 'y'

# %%
x = 10

# %%
X = 5

# %%
X is x
# Out:
# False

# %% [markdown]
# ## PEP8 is the bible of python

# %%
numberOfStudents = 1

# %%
NumberOfStudents = 5

# %%
number_of_students = 7  ## snake case

# %%
NumberOfStudents is number_of_students
# Out:
# False

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
## Garbage Collection in Python
