# %%
num = 0

# %%
dir(num)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
num.is_integer()
# Out:
# True

# %%
comp_num = 2 + 3j

# %%
comp_num.real
# Out:
# 2.0

# %%
comp_num.imag
# Out:
# 3.0

# %%
comp_num.conjugate()
# Out:
# (2-3j)

# %%
s = 'Mohsen shakeri'

# %%
s.upper()
# Out:
# 'MOHSEN SHAKERI'

# %%
s.lower()
# Out:
# 'mohsen shakeri'

# %%
s.capitalize()
# Out:
# 'Mohsen shakeri'

# %%
'Ali Hejazi'.lower() in 'Ali Jeldian - Alireza Mohammadi - Amirahmad Ghods - Ali Hejazi'.lower()
# Out:
# True

# %%
s.title()
# Out:
# 'Mohsen Shakeri'

# %%
s.swapcase()
# Out:
# 'mOHSEN SHAKERI'

# %%
s.lower().count('s')
# Out:
# 2

# %%
s.endswith('i')
# Out:
# True

# %%
s.startswith('M')
# Out:
# True

# %%
s.lower().find('n')
# Out:
# 5

# %%
s.lower().find('sh', 5, -1)
# Out:
# 7

# %%
s.lower().index('n')
# Out:
# 5

# %%
s.rfind('@')
# Out:
# -1

# %%
s.replace('Mohsen', '')
# Out:
# ' shakeri'

# %%
import re

# %%
s = '123x@'

# %%
s.isalnum()
# Out:
# False

# %%
if s.isalnum():
    print(s)
else:
    print('not alpha-number')
# Out:
# not alpha-number

# %%
'foo32'.isidentifier()
# Out:
# True

# %%
'32foo'.isidentifier()
# Out:
# False

# %%
s = 'xasflwqif'

# %%
s.islower()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s = '    \t \n'

# %%
s.isspace()
# Out:
# True

# %%
len(dir(s))
# Out:
# 81

# %%
s = ' alja la lasdkwop.    '

# %%
s.lstrip()
# Out:
# 'alja la lasdkwop.    '

# %%
s.rstrip()
# Out:
# ' alja la lasdkwop.'

# %%
s = 'abc'

# %%
s.center(30)
# Out:
# '             abc              '

# %%
s.center(30, '-')
# Out:
# '-------------abc--------------'

# %%
s.ljust(30)
# Out:
# 'abc                           '

# %%
s.rjust(30)
# Out:
# '                           abc'

# %%
names = [ 
    'Mohsen Aliyary',
    'Alireza Shahi',
    'Aref Abdollahi',
    'Abbas Arefzadeh',
]

# %%
'*'.join(names)
# Out:
# 'Mohsen Aliyary*Alireza Shahi*Aref Abdollahi*Abbas Arefzadeh'

# %%
names.append('Kia Farshi')

# %%
names.extend(['Ali Shiri', 'Hosein Mahgardi'])

# %%
names
# Out:
# ['Mohsen Aliyary',
#  'Alireza Shahi',
#  'Aref Abdollahi',
#  'Abbas Arefzadeh',
#  'Kia Farshi',
#  'Ali Shiri',
#  'Hosein Mahgardi']

# %%
names = names + ['Elly Ace', 'Brad Pitt']

# %%
names
# Out:
# ['Mohsen Aliyary',
#  'Alireza Shahi',
#  'Aref Abdollahi',
#  'Abbas Arefzadeh',
#  'Kia Farshi',
#  'Ali Shiri',
#  'Hosein Mahgardi',
#  'Elly Ace',
#  'Brad Pitt']

# %%
names.insert(2, 'Elahe Izadi')

# %%
names
# Out:
# ['Mohsen Aliyary',
#  'Alireza Shahi',
#  'Elahe Izadi',
#  'Aref Abdollahi',
#  'Abbas Arefzadeh',
#  'Kia Farshi',
#  'Ali Shiri',
#  'Hosein Mahgardi',
#  'Elly Ace',
#  'Brad Pitt']

# %%
names.pop()
# Out:
# 'Brad Pitt'

# %%
names.pop()
# Out:
# 'Elly Ace'

# %%
t = ('Mohsen Aliyary',
 'Alireza Shahi',
 'Elahe Izadi',
 'Aref Abdollahi',
 'Abbas Arefzadeh',
 'Kia Farshi',
 'Ali Shiri',
 'Hosein Mahgardi',
 'Elly Ace',
 'Brad Pitt')

# %%
t = (1, 2, 3, 5, 6, 4, 5, 6)

# %%
t.count(3)
# Out:
# 1

# %%
d = {
    'name': 'Mohsen',
    'last_name': 'Shakeri',
    'age' : 32,
}

# %%
d
# Out:
# {'name': 'Mohsen', 'last_name': 'Shakeri', 'age': 32}

# %%
d.clear()

# %%
x = d.get('name')
x
# Out:
# 'Mohsen'

# %%
d.get('last_name')
# Out:
# 'Shakeri'

# %%
d.get('age')
# Out:
# 32

# %%
d.items()
# Out:
# dict_items([('name', 'Mohsen'), ('last_name', 'Shakeri'), ('age', 32)])

# %%
d.keys()
# Out:
# dict_keys(['name', 'last_name', 'age'])

# %%
d.values()
# Out:
# dict_values(['Mohsen', 'Shakeri', 32])

# %%
d.pop('name')
# Out:
# 'Mohsen'

# %%
d
# Out:
# {'last_name': 'Shakeri', 'age': 32}

# %%
d.update(
    {
        'name' : 'Reza',
        'wife' : 'None'
    }
)

# %%
d
# Out:
# {'last_name': 'Shakeri', 'age': 32, 'name': 'Reza', 'wife': 'None'}

# %%
d2 = {
    'family': 'Geramy',
    'sen': 22,
    'nam': 'Ali',
    'hamsar': 'Hasti',
}

# %%
d3 = {**d, **d2}

# %%
d3
# Out:
# {'last_name': 'Shakeri',
#  'age': 32,
#  'name': 'Reza',
#  'wife': 'None',
#  'family': 'Geramy',
#  'sen': 22,
#  'nam': 'Ali',
#  'hamsar': 'Hasti'}

# %%
len(dir(d))
# Out:
# 46

# %%
s = {
    'Mohsen',
    'Mahsa',
    'Nikan',
    'Niusha'
}

# %%
s1 = {1, 2, 3, 4, 5, 6, 7}

# %%
s2 = {3, 5, 7, 9, 11}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 11}

# %%
s.intersection(s2)
# Out:
# {3, 5, 7}

# %%
s1.difference(s2)
# Out:
# {1, 2, 4, 6}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 11}

# %%
s1 - s2
# Out:
# {1, 2, 4, 6}

# %%
s1 & s2
# Out:
# {3, 5, 7}

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s2
# Out:
# {3, 5, 7, 9, 11}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 4, 6, 9, 11}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.issubset(s2)
# Out:
# False

# %%
s1.issuperset(s2)
# Out:
# False

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 11}

# %%
s1.add(12)

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 11, 12}

# %%
s1.clear()

# %%
s1.add(3)

# %%
s1.discard(3)
