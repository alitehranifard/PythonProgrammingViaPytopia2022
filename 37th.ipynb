# %%
'file.txt'
'./file.txt'
# Out:
# './file.txt'

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
ord('A')
# Out:
# 65

# %%
print(f'{str(int(ord('A')) + 32)}')
# Out:
# 97

# %%
chr(0b00101001)
# Out:
# ')'

# %%
# %%writefile file.txt
# this is line 1
# this is line 2
# this is line 3
# this is line 4
# this is whaaat ?
# Out:
# Overwriting file.txt

# %%
f = open('file.txt')

# %%
for line in f:
    print(line, end='')
# Out:
# this is line 1
# this is line 2
# this is line 3
# this is line 4
# this is whaaat ?

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is line 1\nthis is line 2\nthis is line 3\nthis is line 4\nthis is whaaat ?\n'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is line 1\nthis is line 2\nthis is line 3\nthis is line 4\nthis is whaaat ?\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read(2)
# Out:
# 'th'

# %%
f.read(2)
# Out:
# 'is'

# %%
f.readlines()
# Out:
# [' is line 1\n',
#  'this is line 2\n',
#  'this is line 3\n',
#  'this is line 4\n',
#  'this is whaaat ?\n']

# %%
f.seek(0)
# Out:
# 0

# %%
f.read().split('\n')
# Out:
# ['this is line 1',
#  'this is line 2',
#  'this is line 3',
#  'this is line 4',
#  'this is whaaat ?',
#  '']

# %%
len(dir(f))
# Out:
# 63

# %%
f.read()
# Out:
# ''

# %%
f.close()

# %%
with open('file.txt') as f:
    print(f.read())
# Out:
# this is line 1
# this is line 2
# this is line 3
# this is line 4
# this is whaaat ?

# %%
#you'll face an 
# error because 
# after the above
#  cell is done,
#  the file is closed
# f.read()

# %%
with open('file.txt') as f:
    for line in f:
        print(line, end='')
# Out:
# this is line 1
# this is line 2
# this is line 3
# this is line 4
# this is whaaat ?

# %%
with open('file.txt', 'w') as f:

# %%
f = open('file.txt')

# %%
f = open('file.txt', 'w')

# %%
f.write('this is a new whaaaat?\n')
# Out:
# 23

# %%
f.close()

# %%
with open('file.txt', 'w') as f:
    f.write('this is another line\n')
    f.write('aaaaandd its gone!\n')

# %%
with open('file.txt', 'a') as f:
    f.write('wow we have a history now!\n')

# %%
 with open('file1.txt', 'w') as f1, open('file.txt') as f2:
    f1.write('hiiii')
    print(f2.read())
# Out:
# this is another line
# aaaaandd its gone!
# wow we have a history now!wow we have a history now!

# %%
with open('file.txt', 'r+') as f:
    print(f.read())
    f.write('here we come once again\n')
# Out:
# this is another line
# aaaaandd its gone!
# wow we have a history now!wow we have a history now!
# here we come once again
