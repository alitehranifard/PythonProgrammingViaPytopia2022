# %%
print('hello world!')
# Out:
# hello world!

# %%
todo = ['jaroo', 'washing', 'kir', 'kose kiri', 'vay']
todo_list = []

# %%
type(todo)
# Out:
# list

# %% [markdown]
# ## Lists are ordered

# %%
to_do_two = ['vay', 'kose kir', 'kir', 'washing', 'jaroo']

# %%
todo == to_do_two
# Out:
# False

# %%
[1, 2, 3] == [3, 2, 1]
# Out:
# False

# %%
todo is to_do_two
# Out:
# False

# %%
list_all = [1, 'a', False, True, [1,2], (1+3j)]

# %%
names = []
name = input('Enter a name')
while name:
    names.append(name)
    name = input('Enter a name:')

# %%
names[1]
# Out:
# 'jeld'

# %% [markdown]
# ## Indexing & Slicing

# %%
names[0]
# Out:
# 'ali '

# %%
names[:5]
# Out:
# ['ali ', 'jeld', 'jeld', 'ali', 'jeld']

# %%
names[-1]
# Out:
# 'jeld'

# %%
names[:]
# Out:
# ['ali ', 'jeld', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'ali', 'jeld']

# %%
names[:4] + names[4:]
# Out:
# ['ali ', 'jeld', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'ali', 'jeld']

# %%
names[::2]
# Out:
# ['ali ', 'jeld', 'jeld', 'jeld', 'jeld']

# %%
names[::-1]
# Out:
# ['jeld', 'ali', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'jeld', 'ali ']

# %% [markdown]
# ### Slicing does cope the indexes of the List and its not identical to list

# %%
'jeld' not in names
# Out:
# False

# %%
names * 2
# Out:
# ['ali ',
#  'jeld',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali ',
#  'jeld',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld']

# %%
names +=['abbas']

# %%
names
# Out:
# ['ali ', 'jeld', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'abbas']

# %%
len(names)
# Out:
# 10

# %%
name =[['ali', 'jeldian'], 3]

# %%
name[0][1]
# Out:
# 'jeldian'

# %%
name[:3] = [1,2,3,4]

# %%
name
# Out:
# [1, 2, 3, 4]

# %%
names.append(name)

# %%
names
# Out:
# ['ali ',
#  'jeld',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'abbas',
#  [1, 2, 3, 4]]

# %%
names = names[:11]

# %%
names
# Out:
# ['ali ',
#  'jeld',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'abbas',
#  [1, 2, 3, 4]]

# %%
names = names [:10]

# %%
names
# Out:
# ['ali ', 'jeld', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'ali', 'jeld', 'abbas']

# %%
names += ['kir baba kir']

# %%
names
# Out:
# ['ali ',
#  'jeld',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'ali',
#  'jeld',
#  'abbas',
#  'kir baba kir']
