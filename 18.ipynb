# %%
user = 'Ali'
age = 17

if user == 'Ali':
    if age < 18:
        print('user is 18')
# Out:
# user is 18

# %%
x = 31235
if x > 0:
    print('x is positive')
else:
    print('x is negative')
# Out:
# x is positive

# %%
if x == 0:
    print('0')
elif x == 3:
    print('3')
elif x == 4:
    print('4')
else:
    print('none of the above!')
# Out:
# none of the above!

# %%
print('x is 2') if x==2 else print('x is not 2')
# Out:
# x is not 2

# %%
user_logged_in = True
if user_logged_in:
    pass
else : 
    pass
