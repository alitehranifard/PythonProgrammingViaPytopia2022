# %%
a = 300
b = 124
mylist = [300, 124, 100]

# %%
id(a) != id(mylist[0]) and id(b) == id(mylist[1])
# Out:
# True

# %%
persian_gulf_standing = [
    ['Esteghlal F.C', 2],
    ['Sepahan', 1],
    ['Perspolis', 5],
    ['Gol Gohar', 3],
    ['Foolad', 4],
]

# %%
persian_gulf_standing[4][0]
# Out:
# 'Foolad'

# %%
num_list = [3, 47, 10, 15, 21, 28, 13, 45, 66, 12, 34 ,56, 78]
max(num_list)
# Out:
# 78

# %%
sorted(num_list)[-2]
# Out:
# 66

# %%
sorted(num_list, reverse=True)[1]
# Out:
# 66

# %%
max_1 = num_list[0]
max_2 = num_list[1]

if max_1 < max_2 :
    max_1, max_2 = max_2, max_1

# %%
max_1, max_2
# Out:
# (47, 3)

# %%
for n in num_list[2:]:
    if n > max_1:
        max_2 = max_1
        max_1 = n
    elif n > max_2:
        max_2 = n

# %%
max_1
# Out:
# 78

# %%
max_2
# Out:
# 66

# %%
max(num_list)
# Out:
# 78

# %%
min(num_list)
# Out:
# 3

# %%
sum(num_list)
# Out:
# 428

# %%
mean = sum(num_list) / len(num_list)
mean
# Out:
# 32.92307692307692

# %%
x = [[1,2], [2, 3, 4], [0], []]
y = x.sort(key= lambda item: len(item))
print(y)
# Out:
# None

# %%
mixed_tuple = ('Orange', [10, 20, 30], (5, 15, 25))
value_20 = mixed_tuple[1][1]
value_20
# Out:
# 20

# %%
char_g = mixed_tuple[0][-2]

# %%
mixed_tuple[1].index(20)
# Out:
# 1
