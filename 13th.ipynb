# %%
inp_1 = 10
inp_2 = 35
result = inp_1 + inp_2

# %%
x_1 = input('enter a number')

# %%
x_1 = int(x_1)

# %%
x_1
# Out:
# 29

# %%
tmp = 3

# %%
del tmp

# %%
var_s, var_i, var_f = 'pytopia', 2022, 3.14
