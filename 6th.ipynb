# %%
x = {}
type(x)
# Out:
# dict

# %%
x = ()

# %%
type(x)
# Out:
# tuple

# %% [markdown]
# ## Tuples are immutable

# %%
t = (1,2,3,4)
mylist = ['A']

# %%
mylist[0] = 'Ali'

# %%
import sys 
sys.getsizeof(())
# Out:
# 40

# %%
sys.getsizeof([])
# Out:
# 56

# %%
mytuple = () 
type(mytuple)
# Out:
# tuple

# %%
tuple = (1,)

# %%
list('aliiiii')
# Out:
# ['a', 'l', 'i', 'i', 'i', 'i', 'i']

# %%
list[1,2,3,4,5,6,7,8]
# Out:
# list[1, 2, 3, 4, 5, 6, 7, 8]

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
1, 2
# Out:
# (1, 2)

# %%
x = 2 
y = 3 
x, y
# Out:
# (2, 3)

# %% [markdown]
# ## packing & unpacking

# %%
t = ('Ali', 'Reza', 'Hasan', 'Mahsa', 'Niloufar')

# %%
n1, n2, n3, n4, n5 = t

# %%
n1
# Out:
# 'Ali'

# %%
x1, x2 = 3, 4

# %%
x = [1,2,3,4]
x1, x2, x3, x4 = x

# %%
x2
# Out:
# 2
