# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
    def perimeter(self):
        return (2 * self.length) + (2 * self.width)

# %%
class quare:
    def __init__(self, length):
        self.length = length
    def area(self):
        return self.length * self.length
    def perimeter(self):
        return self.length * 4

# %%
class Square(Rectangle):
    def __init__(self,length):
        self.length = length
        self.width = length

# %%
s = Square(3)
s.area()
# Out:
# 9

# %%
s.perimeter()
# Out:
# 12

# %%
class Square(Rectangle):
    def __init__(self,length):
        #self.length = length
        #self.width = length
        Rectangle.__init__(self, length, length)

# %%
s.area()
# Out:
# 9

# %%
s = Square(4)

# %%
s.perimeter()
# Out:
# 16

# %%
class Square(Rectangle):
    def __init__(self,length):
        #self.length = length
        #self.width = length
        Rectangle.__init__(self, length, length)

# %%
r = Rectangle(3, 4)

# %%
class Square(Rectangle):
    def __init__(self,length):
        super(Square, self).__init__(length, length)

# %%
s = Square(5)

# %%
s.area()
# Out:
# 25

# %%
class Vehicle(object):
    def __init__(self):
        pass

# %%
obj = Vehicle()

# %%
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Vehicle(object):
    def __init__(self, max_speed, mileage, capacity):
        self.max_speed = max_speed
        self.mileage = mileage
        self.capacity = capacity
    def fare(self):
        return self.capacity * 200

# %%
tesla = Vehicle(320, 650,4)

# %%
tesla.max_speed
# Out:
# 320

# %%
tesla.mileage
# Out:
# 650

# %%
class Bus(Vehicle):
    def fare(self):
        return super().fare() * 1.1

# %%
school_bus = Bus(120, 650, 5)

# %%
school_bus.fare()
# Out:
# 1100.0

# %%
class Train:
    def __init__ (
                self,
                last_visited_city: str,
                weight_capacity: float,
                is_on_trip: bool
                ):
    
        self.last_visited_city = last_visited_city
        self.weight_capacity = weight_capacity
        self.is_on_trip = is_on_trip

# %%
class Trip:
    all_cities = [
        'Arak', 'Ardabil', 'Urmia', 'Isfahan', 'Ahvaz',
         'Tehran', 'Kashan', 'Ilam', 'Bojnord', 'Birjand', 'AranVaBidgol']
    def __init__ (
                self,
                train: Train,
                origin_city: str,
                destination_city: str,
                 ):
                 if type(train) != Train :
                    raise Exception('This input is not a train')
                 self.train = train
                 self.origin_city = origin_city
                 self.destination_city = destination_city
                 self.passengers = []
    def origin_city_validation(self):
        if self.origin_city not in self.all_cities:
            raise Exception('This input is not a verified city!')

        return self.origin_city
    def __call_(self):
        pass

# %%
train = Train('Tehran', 1111200, True)

# %%
t = Trip(train, 'Kashan', 'Qatar')

# %%
class Human:
    pass

# %%
class Women(Human):
    pass

# %%
Women.__bases__
# Out:
# (__main__.Human,)

# %%
Human.__bases__
# Out:
# (object,)

# %%
dir(Human)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']
