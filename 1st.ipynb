# %%
import sys
sys.getsizeof(1)
# Out:
# 28

# %%
sys.getsizeof(1.1)
# Out:
# 24

# %%
x = 5e-100
x
# Out:
# 5e-100

# %%
print(1e-02)
# Out:
# 0.01

# %%
3+3j
# Out:
# (3+3j)

# %%
type(2+2j)
# Out:
# complex

# %%
abs(2+2j)
# Out:
# 2.8284271247461903

# %%
print('i am string')
# Out:
# i am string

# %%
type('i am')
# Out:
# str

# %%
type('293')
# Out:
# str

# %%
print('Ali\nReza')
# Out:
# Ali
# Reza

# %%
print(r'\u2192')
# Out:
# \u2192

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(1e-02)
# Out:
# float

# %%
2 * 2 == 4
# Out:
# True

# %%
type(True | False)
# Out:
# bool
